# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5 🚀 v7.0-172-gc3c1304 Python-3.10.10 torch-2.0.0+cpu CPU
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 4726.0/8062.4 GB disk)

# %%
from os import listdir
from os.path import isfile, join
import yaml

classes = ['Cardiomegali']
def create_yaml_file(name, classes):
    data = dict(
        train = '/kaggle/input/train-cardiomegali500-class3rad8-illness-cropped/train',
        val   = '/kaggle/input/test-cardiomegali500-class3rad8-illness-cropped/test', 
        names = classes
    )
    with open(name, 'w') as outfile:
        yaml.dump(data, outfile, default_flow_style=False)
        
file_name = 'custom.yaml'
create_yaml_file(file_name, classes)
f = open(file_name, 'r')
print('\nYaml content:')
print(f.read())
# Out:
# Yaml content:
# names:
# - Cardiomegali
# train: /kaggle/input/train-cardiomegali500-class3rad8-illness-cropped/train
# val: /kaggle/input/test-cardiomegali500-class3rad8-illness-cropped/test

# %%
# !WANDB=true python train.py --img 256 --batch 128 --epochs 550 --data custom.yaml --weights yolov5s.pt --cache ram --patience 0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(30,15))
plt.axis('off')
plt.imshow(plt.imread('runs/train/exp/results.png'));

# %%
# !tar -zcvf trained500_500_class3rad8_illness_cropped_batch128_epochs540.tar.gz runs
